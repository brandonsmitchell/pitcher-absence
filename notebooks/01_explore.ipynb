# %%
import pandas as pd

df = pd.read_parquet("../data/raw/statcast_2024.parquet")
df.shape

# %%
df.columns.tolist()

# %%
df[["game_date","player_name","pitcher","pitch_type",
    "release_speed","release_spin_rate"]].head(20)
